# %%
def max_subarray_sum(nums):
    if not nums:
        return 0
    
    max_sum = current_sum = nums[0]
    
    for num in nums[1:]:
        print(num)
        current_sum = max(num, current_sum + num)
        max_sum = max(max_sum, current_sum)
    
    return max_sum

# Example usage:
nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
print("Maximum sum of contiguous subarray:", max_subarray_sum(nums))  # Output: 6 (the subarray [4, -1, 2, 1] has the maximum sum)
# Out:
# 1
# -3
# 4
# -1
# 2
# 1
# -5
# 4
# Maximum sum of contiguous subarray: 6

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def is_balanced(root):
    if not root:
        return True
    return abs(height(root.left) - height(root.right)) <= 1 and is_balanced(root.left) and is_balanced(root.right)

def height(node):
    if not node:
        return 0
    return 1 + max(height(node.left), height(node.right))

# Example usage:
# Construct a binary tree
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.left.left.left = TreeNode(6)

print("Is the tree balanced?", is_balanced(root))  # Output: False
# Out:
# Is the tree balanced? False

# %%
def longest_substring(s):
    if not s:
        return 0
    
    max_length = 0
    start = 0
    seen = {}
    
    for end in range(len(s)):
        if s[end] in seen and start <= seen[s[end]]:
            start = seen[s[end]] + 1
        else:
            max_length = max(max_length, end - start + 1)
        seen[s[end]] = end

    return max_length

# Example usage:
string = "abcabcbbbdef"
print("Longest substring without repeating characters:", longest_substring(string))  # Output: 3 ("abc")
# Out:
# Longest substring without repeating characters: 4

# %%
# def longest_substring(str):
    
#     if len(str)<=1:
#         return len(str)
#     else:
#         max_length =0
#         seen=[]
#         start =0
        
#         for i in range(len(str)):
#             print(max_length)
#             if str[i] in seen:
#                 max_length = max(len(seen), max_length)
#             else:
#                 seen.append(str[i])
#         return max_length
    
# # Example usage:
# string = "abcabcbbbdef"
# print("Longest substring without repeating characters:", longest_substring(string))  # Output: 3 ("abc")

# %%
def longest_substring(str):
    
    if len(str)<=1:
        return len(str)
    else:
        max_length =0
        seen=[]
        start =0
        
        for end in range(len(str)):
            if str(end)
    
# Example usage:
string = "abcabcbbbdef"
print("Longest substring without repeating characters:", longest_substring(string))  # Output: 3 ("abc")

# %%
def factorial(n):
    # Base case: factorial of 0 or 1 is 1
    if n == 0 or n == 1:
        return 1
    # Recursive case: factorial of n is n times factorial of (n-1)
    else:
        return n * factorial(n - 1)

# Example usage:
number = 5
print("Factorial of", number, "is", factorial(number))  # Output: Factorial of 5 is 120
# Out:
# Factorial of 5 is 120

# %%
from re import TEMPLATE
import pandas as pd 
import requests
import csv
import json
from collections import namedtuple
from pprint import pprint


'''
TASK DESCRIPTION
This task includes fetching current weather data from an API, merging it with static city demographic data from a CSV file, and performing basic analysis. We want the OpenWeatherMap API for weather data retrieval and pandas for data manipulation.

1. Find the city with the highest population-to-area ratio and its current weather.
2. Calculate the Temperature to Population Density Ratio.
3. Analyze how humidity levels relate to the size of a city.
4. * Analyze the Weather Condition Distribution by Population.

OpenWatherMap API Key - 89670e662286e9cc5efd815f55e217b3
http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric
'''


''' 
TEST ACCOUNT
test@sqor.io
A!riplit
'''




# def get_weather_data(city, api_key):
#     response = requests.get(f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric')
#     response.raise_for_status()
#     return response.json() 

# def write_to_csv(data, filename):
#   with open(filename, 'w', newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     writer.writerow(data)

# city = pd.read_csv('city_demographics.csv')
# #print(city.head())
# city_list = city['city'].tolist()
# #print(city_list)


# for city in city_list:
#    city_weather = get_weather_data(city, '89670e662286e9cc5efd815f55e217b3')
#    # print(city_weather) 
#    # city_weather_df = pd.read_json(json.dumps(city_weather))
#    city_weather_df= pd.DataFrame(city_weather)
#    write_to_csv(city_weather_df, 'city_weather.csv')

# weather_data = pd.read_csv('city_weather.csv')
# print(weather_data.head())



api_key = '89670e662286e9cc5efd815f55e217b3'
def fetch_weather_data(city):
  url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
  try:
      response = requests.get(url)
      data = response.json()
      return data
  except Exception as e:
      print(f"Error fetching weather data for {city}: {e}")
      return None

# Load city demographic data from CSV file
city_demographics = pd.read_csv("city_demographics.csv")

# Fetch weather data for each city and store in a list
weather_data = []
for city in city_demographics["city"]:
  city_weather = fetch_weather_data(city)
  if city_weather:
      weather_data.append(city_weather)

# Create a DataFrame from the weather data
weather_df = pd.DataFrame(weather_data)
pd.set_option('display.max_columns', None)
# Merge city demographic data with weather data
print(weather_df.head())
merged_data = pd.merge(city_demographics, weather_df, left_on="city", right_on="name", how="inner")

# 1. Find the city with the highest population-to-area ratio and its current weather.
merged_data["population_density"] = merged_data["population"] / merged_data["area"]
print(merged_data["main"]["temp"])
city_highest_ratio = merged_data.loc[merged_data["population_density"].idxmax()]
print("City with the highest population-to-area ratio:")
print(city_highest_ratio[["city", "population_density"]])
print("Current weather in the city:")

# 2. Calculate the Temperature to Population Density Ratio.print("\nTemperature to Population Density Ratio:")

merged_data["Temperature_to_Population_Density_Ratio"] = merged_data["main"]["temp"] / merged_data["population_density"]

print(merged_data[["city", "Temperature_to_Population_Density_Ratio"]])

# 3. Analyze how humidity levels relate to the size of a city.
print("\nCorrelation between humidity levels and city size:")
print(merged_data[["city", "humidity", "population"]].corr())

# 4. Analyze the Weather Condition Distribution by Population.
weather_condition_distribution = merged_data.groupby("main")["population"].sum()
print("\nWeather Condition Distribution by Population:")
print(weather_condition_distribution)
