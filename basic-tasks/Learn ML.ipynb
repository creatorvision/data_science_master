# %%
import numpy as np
import pandas as pd
import missingno as msno

df = pd.DataFrame({'age': [10, 20, np.nan, 30, 40]})

# Detect missing data
missing_mask = df['age'].isnull()

# Visualize missing data
msno.matrix(df)

# Fill missing data with mean
df['age'].fillna(df['age'].mean(), inplace=True)

# Delete rows with missing data
df = df.dropna()

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: seaborn in c:\users\creat\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: matplotlib in c:\users\creat\anaconda3\lib\site-packages (from missingno) (3.4.3)
# Requirement already satisfied: numpy in c:\users\creat\anaconda3\lib\site-packages (from missingno) (1.20.3)
# Requirement already satisfied: scipy in c:\users\creat\anaconda3\lib\site-packages (from missingno) (1.7.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\creat\anaconda3\lib\site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\creat\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\creat\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\creat\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\creat\anaconda3\lib\site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: six in c:\users\creat\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\creat\anaconda3\lib\site-packages (from seaborn->missingno) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\creat\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'age': [10,20,30,40,50,10,20,20,30,40,10,10,10,20,20]})

df['age'].plot.hist()

plt.show()
