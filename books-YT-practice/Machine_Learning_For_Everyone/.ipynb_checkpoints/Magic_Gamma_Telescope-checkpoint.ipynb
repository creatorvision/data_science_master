# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\creat\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\creat\anaconda3\lib\site-packages (from imblearn) (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\creat\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\creat\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\creat\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\creat\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\creat\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Successfully installed numpy-1.22.4
# WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for grpcio: [Errno 2] No such file or directory: 'c:\\users\\creat\\anaconda3\\lib\\site-packages\\grpcio-1.47.0.dist-info\\METADATA'
#     WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.3.1 requires grpcio<2.0dev,>=1.47.0, which is not installed.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.22.4 which is incompatible.
# google-cloud-bigquery 3.3.1 requires protobuf<4.0.0dev,>=3.12.0, but you have protobuf 4.23.4 which is incompatible.
# WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\creat\anaconda3\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %matplotlib inline

# %% [markdown]
# ## DATASET
# ---
#
# UCI Machine Learning Repository : https://archive.ics.uci.edu/datasets
#
# The data set was generated by a Monte Carlo program, Corsika, described in:
#     D. Heck et al., CORSIKA, A Monte Carlo code to simulate extensive air showers,
#     Forschungszentrum Karlsruhe FZKA 6019 (1998).
# http://rexa.info/paper?id=ac6e674e9af20979b23d3ed4521f1570765e8d68

# %%
cols=['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class']
df= pd.read_csv('magic_gamma_telescope_data/magic04.data', names=cols)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df['class'].unique()
# Out:
# array(['g', 'h'], dtype=object)

# %%
df['class']=(df['class']=='g').astype(int)

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
for label in cols[:-1]:
  plt.hist(df[df['class']==1][label], color = 'blue', label='gamma', alpha = 0.7 , density = True)
  plt.hist(df[df['class']==0][label], color = 'red', label='hadron', alpha = 0.7 , density = True)
  plt.title(label)
  plt.xlabel(label)
  plt.ylabel("probability")
  plt.legend()
  plt.show()

# %% [markdown]
# # Preprocesing
# - Split into train, validate and test
# - Scale and perform oversampling

# %%
train,validate,test = np.split(df.sample(frac=1),[int(0.6*len(df)),int(0.8*len(df))])

# %%
def scale(dataframe, oversample=False):
  x = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values

  scaler = StandardScaler()
  X = scaler.fit_transform(x)

  if oversample:
    ros = RandomOverSampler()
    X,y = ros.fit_resample(X,y)

  data = np.hstack((X, np.reshape(y,(-1,1))))
  return data, X, y

# %%
print(len(df[df["class"]==1]))
print(len(df[df["class"]==0]))

print(len(train[train["class"]==1]))
print(len(train[train["class"]==0]))
# Out:
# 12332
# 6688
# 7354
# 4058

# %%
train, X_train, y_train = scale(train, oversample = True)
test, X_test, y_test = scale(test, oversample = False)
valid, X_valid, y_valid = scale(validate, oversample = False)

# %% [markdown]
# ## **KNN**

# %% [markdown]
# ## K-Nearest Neighbour Algorithm
#
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
knn_model = KNeighborsClassifier(n_neighbors = 5)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(X_test)

# %%
print(y_pred)
print(y_test)
# Out:
# [0 0 0 ... 1 0 1]
# [0 0 0 ... 1 0 1]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74      1311
#            1       0.86      0.87      0.87      2493
#
#     accuracy                           0.82      3804
#    macro avg       0.81      0.80      0.80      3804
# weighted avg       0.82      0.82      0.82      3804

# %% [markdown]
# ## **Navie Bayes**

# %% [markdown]
# ## Navie Bayes
#
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.41      0.51      1311
#            1       0.74      0.90      0.81      2493
#
#     accuracy                           0.73      3804
#    macro avg       0.71      0.66      0.66      3804
# weighted avg       0.72      0.73      0.71      3804

# %% [markdown]
# # Logistic Regression
#
# This type of statistical model (also known as logit model) is often used for classification and predictive analytics. Logistic regression estimates the probability of an event occurring, such as voted or didn't vote, based on a given dataset of independent variables.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import LogisticRegression

lg_model = LogisticRegression()
lg_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = nb_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.41      0.51      1311
#            1       0.74      0.90      0.81      2493
#
#     accuracy                           0.73      3804
#    macro avg       0.71      0.66      0.66      3804
# weighted avg       0.72      0.73      0.71      3804

# %% [markdown]
# #SVM (Support Vector Machine)
#
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.svm import SVC # support vector classifier

svm_model = SVC( kernel = 'rbf') # using radial basis function / gaussian kernel
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      1311
#            1       0.90      0.90      0.90      2493
#
#     accuracy                           0.87      3804
#    macro avg       0.85      0.85      0.85      3804
# weighted avg       0.87      0.87      0.87      3804

# %% [markdown]
# # Neural Network (Basics)
#
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf

nm_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(10,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

nm_model.compile(optimizer = tf.keras.optimizers.Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# summarize history for accuracy
def plot_accuracy(history):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
# summarize history for loss
def plot_loss(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
history = nm_model.fit(
    X_train,y_train,
    epochs=100, batch_size=32, validation_split =0.2
)
# Out:
# Epoch 1/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.4766 - accuracy: 0.7706 - val_loss: 0.6161 - val_accuracy: 0.6366
# Epoch 2/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.8311 - val_loss: 0.6111 - val_accuracy: 0.6798
# Epoch 3/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.3616 - accuracy: 0.8506 - val_loss: 0.5215 - val_accuracy: 0.7315
# Epoch 4/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8548 - val_loss: 0.4906 - val_accuracy: 0.7519
# Epoch 5/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3410 - accuracy: 0.8590 - val_loss: 0.5521 - val_accuracy: 0.7138
# Epoch 6/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8591 - val_loss: 0.4623 - val_accuracy: 0.7682
# Epoch 7/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8612 - val_loss: 0.5482 - val_accuracy: 0.7264
# Epoch 8/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3282 - accuracy: 0.8639 - val_loss: 0.4856 - val_accuracy: 0.7471
# Epoch 9/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3248 - accuracy: 0.8645 - val_loss: 0.5133 - val_accuracy: 0.7454
# Epoch 10/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3206 - accuracy: 0.8646 - val_loss: 0.4684 - val_accuracy: 0.7549
# Epoch 11/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3194 - accuracy: 0.8664 - val_loss: 0.4049 - val_accuracy: 0.7940
# Epoch 12/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3168 - accuracy: 0.8674 - val_loss: 0.4947 - val_accuracy: 0.7407
# Epoch 13/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3143 - accuracy: 0.8686 - val_loss: 0.4834 - val_accuracy: 0.7437
# Epoch 14/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3127 - accuracy: 0.8687 - val_loss: 0.5846 - val_accuracy: 0.6968
# Epoch 15/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3119 - accuracy: 0.8699 - val_loss: 0.4915 - val_accuracy: 0.7475
# Epoch 16/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3095 - accuracy: 0.8684 - val_loss: 0.4593 - val_accuracy: 0.7614
# Epoch 17/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.3089 - accuracy: 0.8706 - val_loss: 0.4708 - val_accuracy: 0.7508
# Epoch 18/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.3077 - accuracy: 0.8712 - val_loss: 0.4772 - val_accuracy: 0.7559
# Epoch 19/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.3055 - accuracy: 0.8731 - val_loss: 0.4173 - val_accuracy: 0.7831
# Epoch 20/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.3049 - accuracy: 0.8732 - val_loss: 0.4474 - val_accuracy: 0.7563
# Epoch 21/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3040 - accuracy: 0.8721 - val_loss: 0.4433 - val_accuracy: 0.7593
# Epoch 22/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3025 - accuracy: 0.8735 - val_loss: 0.4979 - val_accuracy: 0.7396
# Epoch 23/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.3015 - accuracy: 0.8737 - val_loss: 0.4715 - val_accuracy: 0.7522
# Epoch 24/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.3015 - accuracy: 0.8719 - val_loss: 0.5071 - val_accuracy: 0.7437
# Epoch 25/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2989 - accuracy: 0.8741 - val_loss: 0.4913 - val_accuracy: 0.7396
# Epoch 26/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2986 - accuracy: 0.8734 - val_loss: 0.4260 - val_accuracy: 0.7716
# Epoch 27/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.8732 - val_loss: 0.4380 - val_accuracy: 0.7692
# Epoch 28/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2957 - accuracy: 0.8747 - val_loss: 0.4997 - val_accuracy: 0.7454
# Epoch 29/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2958 - accuracy: 0.8747 - val_loss: 0.4485 - val_accuracy: 0.7621
# Epoch 30/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2949 - accuracy: 0.8757 - val_loss: 0.4546 - val_accuracy: 0.7675
# Epoch 31/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2929 - accuracy: 0.8761 - val_loss: 0.5031 - val_accuracy: 0.7498
# Epoch 32/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2930 - accuracy: 0.8773 - val_loss: 0.4279 - val_accuracy: 0.7716
# Epoch 33/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2933 - accuracy: 0.8770 - val_loss: 0.5032 - val_accuracy: 0.7444
# Epoch 34/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2920 - accuracy: 0.8771 - val_loss: 0.4762 - val_accuracy: 0.7580
# Epoch 35/100
# 368/368 [==============================] - 0s 991us/step - loss: 0.2913 - accuracy: 0.8780 - val_loss: 0.4374 - val_accuracy: 0.7634
# Epoch 36/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2904 - accuracy: 0.8768 - val_loss: 0.4346 - val_accuracy: 0.7750
# Epoch 37/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2893 - accuracy: 0.8778 - val_loss: 0.4279 - val_accuracy: 0.7753
# Epoch 38/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2889 - accuracy: 0.8782 - val_loss: 0.4100 - val_accuracy: 0.7855
# Epoch 39/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2890 - accuracy: 0.8792 - val_loss: 0.4501 - val_accuracy: 0.7587
# Epoch 40/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2870 - accuracy: 0.8774 - val_loss: 0.4501 - val_accuracy: 0.7706
# Epoch 41/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2877 - accuracy: 0.8784 - val_loss: 0.4153 - val_accuracy: 0.7838
# Epoch 42/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2871 - accuracy: 0.8774 - val_loss: 0.4111 - val_accuracy: 0.7835
# Epoch 43/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2866 - accuracy: 0.8807 - val_loss: 0.4251 - val_accuracy: 0.7760
# Epoch 44/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2855 - accuracy: 0.8795 - val_loss: 0.4035 - val_accuracy: 0.7869
# Epoch 45/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2852 - accuracy: 0.8792 - val_loss: 0.4494 - val_accuracy: 0.7607
# Epoch 46/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2837 - accuracy: 0.8799 - val_loss: 0.3867 - val_accuracy: 0.7879
# Epoch 47/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2840 - accuracy: 0.8779 - val_loss: 0.4452 - val_accuracy: 0.7638
# Epoch 48/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2836 - accuracy: 0.8802 - val_loss: 0.3935 - val_accuracy: 0.7903
# Epoch 49/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2819 - accuracy: 0.8785 - val_loss: 0.4223 - val_accuracy: 0.7777
# Epoch 50/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2821 - accuracy: 0.8794 - val_loss: 0.4410 - val_accuracy: 0.7689
# Epoch 51/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2812 - accuracy: 0.8780 - val_loss: 0.3868 - val_accuracy: 0.7978
# Epoch 52/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2815 - accuracy: 0.8827 - val_loss: 0.4318 - val_accuracy: 0.7695
# Epoch 53/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2806 - accuracy: 0.8802 - val_loss: 0.4150 - val_accuracy: 0.7886
# Epoch 54/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2806 - accuracy: 0.8814 - val_loss: 0.5198 - val_accuracy: 0.7369
# Epoch 55/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2800 - accuracy: 0.8811 - val_loss: 0.3899 - val_accuracy: 0.8001
# Epoch 56/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2793 - accuracy: 0.8808 - val_loss: 0.4308 - val_accuracy: 0.7706
# Epoch 57/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2787 - accuracy: 0.8792 - val_loss: 0.4026 - val_accuracy: 0.7838
# Epoch 58/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2780 - accuracy: 0.8812 - val_loss: 0.4514 - val_accuracy: 0.7675
# Epoch 59/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2784 - accuracy: 0.8818 - val_loss: 0.4659 - val_accuracy: 0.7631
# Epoch 60/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2770 - accuracy: 0.8835 - val_loss: 0.3727 - val_accuracy: 0.8069
# Epoch 61/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2759 - accuracy: 0.8819 - val_loss: 0.3904 - val_accuracy: 0.7893
# Epoch 62/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2771 - accuracy: 0.8831 - val_loss: 0.4427 - val_accuracy: 0.7709
# Epoch 63/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2772 - accuracy: 0.8824 - val_loss: 0.4619 - val_accuracy: 0.7604
# Epoch 64/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2754 - accuracy: 0.8831 - val_loss: 0.4029 - val_accuracy: 0.7961
# Epoch 65/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2753 - accuracy: 0.8826 - val_loss: 0.3924 - val_accuracy: 0.7910
# Epoch 66/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2752 - accuracy: 0.8842 - val_loss: 0.4693 - val_accuracy: 0.7519
# Epoch 67/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2751 - accuracy: 0.8846 - val_loss: 0.4008 - val_accuracy: 0.7927
# Epoch 68/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2734 - accuracy: 0.8857 - val_loss: 0.4286 - val_accuracy: 0.7797
# Epoch 69/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2732 - accuracy: 0.8850 - val_loss: 0.4045 - val_accuracy: 0.7876
# Epoch 70/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2726 - accuracy: 0.8836 - val_loss: 0.4555 - val_accuracy: 0.7661
# Epoch 71/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2731 - accuracy: 0.8838 - val_loss: 0.4389 - val_accuracy: 0.7743
# Epoch 72/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2728 - accuracy: 0.8849 - val_loss: 0.3897 - val_accuracy: 0.7913
# Epoch 73/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2728 - accuracy: 0.8840 - val_loss: 0.4254 - val_accuracy: 0.7804
# Epoch 74/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2714 - accuracy: 0.8863 - val_loss: 0.4223 - val_accuracy: 0.7753
# Epoch 75/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2710 - accuracy: 0.8862 - val_loss: 0.4355 - val_accuracy: 0.7746
# Epoch 76/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2704 - accuracy: 0.8859 - val_loss: 0.4410 - val_accuracy: 0.7678
# Epoch 77/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2699 - accuracy: 0.8844 - val_loss: 0.4235 - val_accuracy: 0.7787
# Epoch 78/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2707 - accuracy: 0.8839 - val_loss: 0.3812 - val_accuracy: 0.8063
# Epoch 79/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2687 - accuracy: 0.8876 - val_loss: 0.3980 - val_accuracy: 0.7889
# Epoch 80/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2695 - accuracy: 0.8859 - val_loss: 0.4641 - val_accuracy: 0.7587
# Epoch 81/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2698 - accuracy: 0.8855 - val_loss: 0.4381 - val_accuracy: 0.7641
# Epoch 82/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2690 - accuracy: 0.8874 - val_loss: 0.4171 - val_accuracy: 0.7882
# Epoch 83/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2683 - accuracy: 0.8863 - val_loss: 0.4372 - val_accuracy: 0.7746
# Epoch 84/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2669 - accuracy: 0.8860 - val_loss: 0.4330 - val_accuracy: 0.7811
# Epoch 85/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2683 - accuracy: 0.8871 - val_loss: 0.4131 - val_accuracy: 0.7899
# Epoch 86/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2669 - accuracy: 0.8867 - val_loss: 0.4660 - val_accuracy: 0.7685
# Epoch 87/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2664 - accuracy: 0.8856 - val_loss: 0.4138 - val_accuracy: 0.7835
# Epoch 88/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2672 - accuracy: 0.8862 - val_loss: 0.3507 - val_accuracy: 0.8141
# Epoch 89/100
# 368/368 [==============================] - 1s 2ms/step - loss: 0.2665 - accuracy: 0.8872 - val_loss: 0.4481 - val_accuracy: 0.7750
# Epoch 90/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2662 - accuracy: 0.8864 - val_loss: 0.4404 - val_accuracy: 0.7774
# Epoch 91/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2662 - accuracy: 0.8874 - val_loss: 0.4254 - val_accuracy: 0.7763
# Epoch 92/100
# 368/368 [==============================] - 0s 988us/step - loss: 0.2652 - accuracy: 0.8862 - val_loss: 0.4086 - val_accuracy: 0.7842
# Epoch 93/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2651 - accuracy: 0.8892 - val_loss: 0.3743 - val_accuracy: 0.8018
# Epoch 94/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2646 - accuracy: 0.8869 - val_loss: 0.4279 - val_accuracy: 0.7845
# Epoch 95/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2642 - accuracy: 0.8884 - val_loss: 0.4221 - val_accuracy: 0.7845
# Epoch 96/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2639 - accuracy: 0.8898 - val_loss: 0.3501 - val_accuracy: 0.8161
# Epoch 97/100
# 368/368 [==============================] - 0s 979us/step - loss: 0.2650 - accuracy: 0.8843 - val_loss: 0.4206 - val_accuracy: 0.7746
# Epoch 98/100
# 368/368 [==============================] - 1s 1ms/step - loss: 0.2636 - accuracy: 0.8874 - val_loss: 0.4473 - val_accuracy: 0.7791
# Epoch 99/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2659 - accuracy: 0.8867 - val_loss: 0.4654 - val_accuracy: 0.7665
# Epoch 100/100
# 368/368 [==============================] - 0s 1ms/step - loss: 0.2631 - accuracy: 0.8889 - val_loss: 0.3668 - val_accuracy: 0.8103

# %%
plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# ## Optimized Code of Neural Network

# %%
# summarize history for accuracy
def plot_history(history):
  fig, (ax1,ax2) = plt.subplots(1,2,figsize =(10,4))
  ax1.plot(history.history['accuracy'])
  ax1.plot(history.history['val_accuracy'])
  ax1.set_ylabel('accuracy')
  ax1.set_xlabel('epoch')
  ax1.legend(['train', 'test'], loc='upper left')

  ax2.plot(history.history['loss'])
  ax2.plot(history.history['val_loss'])
  ax2.set_ylabel('loss')
  ax2.set_xlabel('epoch')
  ax2.legend(['train', 'test'], loc='upper left')

  plt.show()

# %%
plot_history(history)

# %%
import tensorflow as tf

def train_model(X_train,y_train,nodes,droupout_prob,epochs,lr,batch_size,validation_split):
  nm_model = tf.keras.Sequential([
      tf.keras.layers.Dense(nodes, activation='relu', input_shape=(10,)),
      tf.keras.layers.Dropout(droupout_prob),
      tf.keras.layers.Dense(nodes, activation='relu'),
      tf.keras.layers.Dropout(droupout_prob),
      tf.keras.layers.Dense(1, activation='sigmoid')
  ])

  nm_model.compile(optimizer = tf.keras.optimizers.Adam(lr), loss='binary_crossentropy', metrics=['accuracy']) # lr is learning rate
  history = nm_model.fit(
      X_train,y_train,epochs=epochs, batch_size=batch_size, validation_split = validation_split, verbose =0
  )
  return nm_model,history

# %%
least_loss = float('inf')
least_loss_model = None
epochs =100
validation_split = 0.02

for nd in [16,32,64]:
  for dp in [0.1,0.2,0.25]:
    for lr in [0.01,0.005,0.001]:
      for bs in [64,128]:
        # Number of runs = 3*3*3*2 = 54
        print(f"Nodes: {nd} , dropout rate: {dp}, learning rate: {lr} and batch size: {bs}")
        model, history = train_model(X_train,y_train,nd,dp,epochs,lr,bs,validation_split)
        plot_history(history)
        try:
          loss= model.evaluate(X_valid,y_valid)[0]
        except:
          loss= model.evaluate(X_valid,y_valid)
        print(loss)
        if loss < least_loss:
          least_loss = loss
          least_loss_model = model
# Out:
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.01 and batch size: 32
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3338 - accuracy: 0.8630
# 0.3338426649570465
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.01 and batch size: 64
# 119/119 [==============================] - 0s 879us/step - loss: 0.3287 - accuracy: 0.8670
# 0.3287338614463806
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.01 and batch size: 128
# 119/119 [==============================] - 0s 993us/step - loss: 0.3319 - accuracy: 0.8651
# 0.3319249749183655
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.005 and batch size: 32
# 119/119 [==============================] - 0s 733us/step - loss: 0.3251 - accuracy: 0.8630
# 0.32514315843582153
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.005 and batch size: 64
# 119/119 [==============================] - 0s 942us/step - loss: 0.3254 - accuracy: 0.8641
# 0.32541489601135254
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.005 and batch size: 128
# 119/119 [==============================] - 0s 891us/step - loss: 0.3232 - accuracy: 0.8667
# 0.32319697737693787
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.001 and batch size: 32
# 119/119 [==============================] - 0s 949us/step - loss: 0.3375 - accuracy: 0.8557
# 0.3375421166419983
# Nodes: 16 , dropout rate: 0.1, learning rate: 0.001 and batch size: 64

# %%
y_pred = least_loss_model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).reshape(-1,)
print(classification_report(y_test, y_pred))
