# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/shivanggupta/Desktop/personal/code_v2/data_science_master/machine_leaning_with_python_iimb'

# %%
from pathlib import Path

# home would contain something like "/Users/shivanggupta"
home = str(Path.home())
filepath = home + "/Desktop/personal/code_v2/data_science_master/machine_leaning_with_python_iimb/Machine Learning (Codes and Data Files)/Data/IPL IMB381IPL2013.csv"

print(filepath)
# Out:
# /Users/shivanggupta/Desktop/personal/code_v2/data_science_master/machine_leaning_with_python_iimb/Machine Learning (Codes and Data Files)/Data/IPL IMB381IPL2013.csv

# %%
ipl = pd.read_csv(filepath)

# %%
ipl
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0  \
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
ipl.keys
# Out:
# <bound method NDFrame.keys of      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0  \
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_columns',15)
ipl.head(5)
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  ...  WKTS
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0  ...    15  \
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214  ...     0
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571  ...    29
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284  ...    49
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63  ...     0
#
#    AVE-BL   ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0   20.47   8.90  13.93          2009       50000       50000
# 1    0.00  14.50   0.00          2008       50000       50000
# 2   36.52   8.81  24.90          2008      200000      350000
# 3   22.96   6.23  22.14          2011      100000      850000
# 4    0.00   0.00   0.00          2011      100000      800000
#
# [5 rows x 26 columns]

# %%
list(ipl.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
ipl.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
ipl.shape
# Out:
# (130, 26)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  ...  WKTS
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0  ...    15  \
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214  ...     0
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571  ...    29
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284  ...    49
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63  ...     0
#
#    AVE-BL   ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0   20.47   8.90  13.93          2009       50000       50000
# 1    0.00  14.50   0.00          2008       50000       50000
# 2   36.52   8.81  24.90          2008      200000      350000
# 3   22.96   6.23  22.14          2011      100000      850000
# 4    0.00   0.00   0.00          2011      100000      800000
#
# [5 rows x 26 columns]

# %%
ipl[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  ...  WKTS
# 125     126     Yadav, AS    2     IND     DC      Batsman       0  ...     0  \
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398  ...     0
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775  ...    23
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114  ...    65
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288  ...     2
#
#      AVE-BL  ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 125    0.00  0.00   0.00          2010       50000      750000
# 126    0.00  0.00   0.00          2008      225000      225000
# 127   24.74  7.02  21.13          2011      400000     1800000
# 128   27.43  7.75  21.26          2008      200000      450000
# 129   49.50  9.00  33.00          2008      100000      110000
#
# [5 rows x 26 columns]

# %%
ipl['PLAYER NAME'][0:15]
# Out:
# 0         Abdulla, YA
# 1        Abdur Razzak
# 2         Agarkar, AB
# 3           Ashwin, R
# 4        Badrinath, S
# 5          Bailey, GJ
# 6           Balaji, L
# 7       Bollinger, DE
# 8            Botha, J
# 9         Boucher, MV
# 10          Bravo, DJ
# 11     Chanderpaul, S
# 12         Chawla, PP
# 13    de Villiers, AB
# 14          Dhawan, S
# Name: PLAYER NAME, dtype: object

# %%
ipl[['PLAYER NAME','COUNTRY']][0:15]
# Out:
#         PLAYER NAME COUNTRY
# 0       Abdulla, YA      SA
# 1      Abdur Razzak     BAN
# 2       Agarkar, AB     IND
# 3         Ashwin, R     IND
# 4      Badrinath, S     IND
# 5        Bailey, GJ     AUS
# 6         Balaji, L     IND
# 7     Bollinger, DE     AUS
# 8          Botha, J      SA
# 9       Boucher, MV      SA
# 10        Bravo, DJ      WI
# 11   Chanderpaul, S      WI
# 12       Chawla, PP     IND
# 13  de Villiers, AB      SA
# 14        Dhawan, S     IND

# %%
ipl.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
ipl.COUNTRY.value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
ipl.COUNTRY.value_counts(normalize = True)*100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
pd.crosstab(ipl['AGE'],ipl['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
ipl[['PLAYER NAME','SOLD PRICE']].sort_values(['SOLD PRICE'])[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000

# %%
ipl[['PLAYER NAME','SOLD PRICE']].sort_values(['SOLD PRICE'], ascending = False)[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000

# %%
ipl['premium']= ipl['SOLD PRICE'] - ipl['BASE PRICE']

# %%
ipl[['PLAYER NAME','BASE PRICE','SOLD PRICE','premium']][0:5]
# Out:
#     PLAYER NAME  BASE PRICE  SOLD PRICE  premium
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      200000      350000   150000
# 3     Ashwin, R      100000      850000   750000
# 4  Badrinath, S      100000      800000   700000

# %%
ipl[['PLAYER NAME','BASE PRICE','SOLD PRICE','premium']].sort_values(['premium'], ascending = False)[0:5]
# Out:
#        PLAYER NAME  BASE PRICE  SOLD PRICE  premium
# 50        Kohli, V      150000     1800000  1650000
# 113     Tiwary, SS      100000     1600000  1500000
# 127   Yuvraj Singh      400000     1800000  1400000
# 111  Tendulkar, SR      400000     1800000  1400000
# 93       Sehwag, V      400000     1800000  1400000

# %%
ipl.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
soldprice_by_age = ipl.groupby('AGE')['SOLD PRICE'].mean().reset_index()
print(soldprice_by_age)
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429
